# %%
# !gdown 1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn
# !tar -xf models.zip
# Out:
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn
# From (redirected): https://drive.google.com/uc?id=1ujSYC3tEC3VNoxqUIWO2PG7Lg5HAdYqn&confirm=t&uuid=1b27191c-e7b6-433a-9605-8ffdb866c9ad
# To: e:\License-Plate-Recognition\models.zip
#
#   0%|          | 0.00/305M [00:00<?, ?B/s]
#   0%|          | 524k/305M [00:00<02:22, 2.13MB/s]
#   1%|          | 1.57M/305M [00:00<01:15, 4.01MB/s]
#   1%|          | 2.10M/305M [00:00<01:29, 3.39MB/s]
#   1%|          | 2.62M/305M [00:00<01:37, 3.11MB/s]
#   1%|          | 3.15M/305M [00:01<01:42, 2.94MB/s]
#   1%|          | 3.67M/305M [00:01<01:46, 2.84MB/s]
#   1%|▏         | 4.19M/305M [00:01<01:49, 2.75MB/s]
#   2%|▏         | 4.72M/305M [00:01<01:50, 2.72MB/s]
#   2%|▏         | 5.24M/305M [00:01<01:52, 2.65MB/s]
#   2%|▏         | 5.77M/305M [00:02<01:50, 2.70MB/s]
#   2%|▏         | 6.29M/305M [00:02<01:50, 2.69MB/s]
#   2%|▏         | 6.82M/305M [00:02<01:51, 2.68MB/s]
# ...

# %%
import utils
utils.show_image('images/test_image.jpg')

# %%
utils.detect_and_extract_lp_text('images/test_image.jpg')
# Out:
# ('ঢাকা মেট্রো-গ', '১৯-০৪৭৬')
# ('ঢাকা মেট্রো-গ', '১৯-০৪৭৬')

# %%
utils.show_image('images/My_car_image.jpg')

# %%
utils.detect_and_extract_lp_text('images/My_car_image.jpg')
# Out:
# ('রাজ মেট্রো-ঢ', '১৮-১৫৭১')
# ('রাজ মেট্রো-ঢ', '১৮-১৫৭১')

# %%
utils.show_image('images/dataset-cover.jpg')

# %%
utils.detect_and_extract_lp_text('images/dataset-cover.jpg')
# Out:
# ('ঢাকা মেট্রো-হ', '২১১৫৮১৫')
# ('ঢাকা মেট্রো-হ', '২১১৫৮১৫')

# %%
utils.show_image('images/images.jpg')

# %%
utils.detect_and_extract_lp_text('images/images.jpg')
# Out:
# ('ঢাকা মেট্রো-গ', '-৯৪২৫')
# ('ঢাকা মেট্রো-গ', '-৯৪২৫')

# %%
utils.show_image('images/images (1).jpg')

# %%
utils.detect_and_extract_lp_text('images/images (1).jpg')
# Out:
# ('ঢাকা মেট্রো-হ', '১৬-০৩৮৫')
# ('ঢাকা মেট্রো-হ', '১৬-০৩৮৫')

# %%
utils.show_image('images/4-Figure13-1.png')

# %%
utils.detect_and_extract_lp_text('images/4-Figure13-1.png')
# Out:
# ('ঢাকা মেট্রো-গ', '১৫-০৫৬৮')
# ('ঢাকা মেট্রো-গ', '১৫-০৫৬৮')

# %%
utils.show_image('images/images.jpeg')

# %%
utils.detect_and_extract_lp_text('images/images.jpeg')
# Out:
# ('ঢাকা মেট্রো-খ', '১১-৮০০')
# ('ঢাকা মেট্রো-খ', '১১-৮০০')

# %%
utils.show_image('images/WhatsApp Image 2023-10-21 at 09.36.57_44f430d5.jpg')

# %%
utils.detect_and_extract_lp_text('images/WhatsApp Image 2023-10-21 at 09.36.57_44f430d5.jpg')
# Out:
# ('ঢাকা মেট্রো-হ', '২৩-৬৬৩')
# ('ঢাকা মেট্রো-হ', '২৩-৬৬৩')

# %%
utils.show_image('images/WhatsApp Image 2023-10-21 at 09.36.58_0336c795.jpg')

# %%
utils.detect_and_extract_lp_text(
    'images/WhatsApp Image 2023-10-21 at 09.36.58_0336c795.jpg')
# Out:
# ('ঢাকা মেট্রো-গ', '৩৬-৭১৯')
# ('ঢাকা মেট্রো-গ', '৩৬-৭১৯')
